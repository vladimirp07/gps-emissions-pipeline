# %% [markdown]
# # Orquestador de Experimentos de Intervención en Ruteo
#
# Este notebook sirve como orquestador para ejecutar la batería completa de experimentos de sensibilidad y calibración espacial/física del ruteador. La lógica de ejecución y graficación está modularizada en `scratch/run_routing_experiments.py`.

# %%
import sys
from pathlib import Path

# Asegurar que la raíz del proyecto está en el path
PROJECT_ROOT = Path("../../")
if str(PROJECT_ROOT.resolve()) not in sys.path:
    sys.path.append(str(PROJECT_ROOT.resolve()))

# Importar y ejecutar la batería de experimentos modularizada
from scratch import run_routing_experiments

run_routing_experiments.main()
